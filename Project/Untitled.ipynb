# %% [markdown]
# ### Factors that can effect performance

# %% [markdown]
# 1. How well did they play when it's their last year of their contract?
# 2. How well did they play before and after the All-Star break?
# 3. Which position hits the best?
