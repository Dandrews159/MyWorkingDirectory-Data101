# %% [markdown]
# Who's been the best hitter in the past 5 years
# -I would look at every Silver Slugger winner from the past 5 years, take their stats, then compare their stats to other players.
# Which position tends to have the highest slugging percentage (SLG)?
# - I could take the best 3 players from each position, then make an average slugging percentage out of those 3 players for each position, then I can make a graph and compare them all.
#
# How does a player’s performance change before and after competing in the star game?
#
# -I could look at the stats of the starting line-up from both teams in the All-Star Game, then I can compare them to their stats before then after the All-Star Game.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("josuefernandezc/mlb-hitting-data-2015-2024")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("josuefernandezc/mlb-hitting-data-2015-2024")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "josuefernandezc/mlb-hitting-data-2015-2024",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Install dependencies as needed:
#       2 # pip install kagglehub[pandas-datasets]
# ----> 3 import kagglehub
#       4 from kagglehub import KaggleDatasetAdapter
#       6 # Set the path to the file you'd like to load
#
# ModuleNotFoundError: No module named 'kagglehub'
