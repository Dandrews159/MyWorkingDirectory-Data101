# %% [markdown]
# ### Project Proposal

# %% [markdown]
# I will be using MLB players' stats from the past 5 seasons to determine are variety of questions I may have, and from these questions I will be able to create plots to show my answers.

# %% [markdown]
# #### Questions

# %% [markdown]
# Who's been the best hitter in the past 5 years?
# -I would look at every Silver Slugger winner from the past 5 years, take their stats (Avg, Slugging, and on-base percentage), then compare their stats to other players.
# Which position tends to have the highest slugging percentage (SLG)?
# - I could take the best 3 players from each position, then make an average slugging percentage out of those 3 players for each position, then I can make a graph and compare them all.
#
# How does a player’s performance change before and after competing in the star game?
#
# -I could look at the stats of the starting line-up from both teams in the All-Star Game, then I can compare them to their stats before then after the All-Star Game.
#
# How different factors may affect a player's performance?
#
# -Age? Salary? Travel? Team? Contract running out?
#
# -With that being said, we will compare all of these factors to player's stats (AVG, slugging percentage, and on-base percentage), then we will compare those findings to other players on the opposite side of the factors, such as comparing a 37-year-old player vs a 27-year-old player.

# %%
import pandas as pd
import numpy as np
#Loading csv
try:
 # File
    DF_mlb = pd.read_csv('mlb-player-stats-Batters.csv')

 # Displaying some initaialinformation  
    print("First 5 rows of the DataFrame:")
    print(DF_mlb.head())
    print("-" * 50)

    #If an error occurs, I will be notified.
except Exception as e:
    print(f"Error: {e}")
# Out:
# First 5 rows of the DataFrame:
#              Player Team Pos  Age    G   AB    R    H  2B  3B  ...  CS  BB  \
# 0   Julio Rodriguez  SEA  OF   24  160  652  106  174  31   4  ...   6  44
# 1  Francisco Lindor  NYM  SS   32  160  644  117  172  35   0  ...   6  65
# 2   Elly De La Cruz  CIN  SS   23  162  629  102  166  31   7  ...   8  67
# 3      Brent Rooker  ATH  OF   31  162  626   92  164  40   3  ...   1  65
# 4       Steven Kwan  CLE  OF   28  156  625   81  170  29   1  ...   5  55
#
#     SO  SH  SF  HBP    AVG    OBP    SLG    OPS
# 0  152   0   2   12  0.267  0.324  0.474  0.798
# 1  131   0   7   16  0.267  0.346  0.466  0.812
# 2  181   0   1    2  0.264  0.336  0.440  0.776
# 3  155   0   2    5  0.262  0.335  0.479  0.814
# 4   60   3   7    3  0.272  0.330  0.374  0.704
#
# [5 rows x 23 columns]
# --------------------------------------------------

# %%
DF_mlb.columns
# Out:
# Index(['Player', 'Team', 'Pos', 'Age', 'G', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'SH', 'SF', 'HBP', 'AVG', 'OBP', 'SLG',
#        'OPS'],
#       dtype='object')
